# %%
import pandas as pd
import numpy as np
from sunpy.net import hek

# %%
cl = pd.read_csv('all_clear/classifications.csv', delimiter=';')
cl.head()
# Out:
#    #id          zooniverse_class  user_id  image_id_0  image_id_1  \
# 0    1  530e4b1b41ecea2100001972        1        1027        8638
# 1    2  530e4b3747bc723aac00187f        1        8061        5991
# 2    3  530e4b3841ecea2100001977        1        6637        6901
# 3    4  530e4b4441ecea211b0018aa        1        9078       10560
# 4    5  530e4b4841ecea210b0018c1        1       10721         168
#
#    image0_more_complex_image1  used_inverted        bin         date_created  \
# 0                           0              0  bin_40_50  2014-02-26 20:14:19
# 1                           0              0  bin_65_90  2014-02-26 20:14:47
# 2                           1              0  bin_50_60  2014-02-26 20:14:48
# 3                           0              0  bin_20_40  2014-02-26 20:15:00
# 4                           0              0  bin_20_40  2014-02-26 20:15:04
#
#           date_started        date_finished
# 0  2014-02-26 20:13:59  2014-02-26 20:14:18
# ...

# %%
r = pd.read_csv('all_clear/rankings.csv', delimiter=';')
lp = pd.read_csv('all_clear/lookup_properties.csv', delimiter=';')
lt = pd.read_csv('all_clear/lookup_timesfits.csv', delimiter=';')

# %%
r.head()
# Out:
#    #id  image_id  count  k_value       score   std_dev
# 0    1      9843     50        8  950.403592  1.455031
# 1    2       999     50        8  953.549821  1.717277
# 2    3      2437     50        8  954.324334  2.209654
# 3    4      5013     50        8  955.205675  1.497922
# 4    5      9473     50        8  956.152484  1.888993

# %%
lp.head()
# Out:
#    #id                      filename zooniverse_id    angle     area  \
# 0    1  530be1183ae74079c300000d.jpg    ASZ000090y  37.8021  34400.0
# 1    2  530be1183ae74079c300000f.jpg    ASZ000090o  37.3590  78700.0
# 2    3  530be1183ae74079c3000011.jpg    ASZ0000946  58.6197  37900.0
# 3    4  530be1183ae74079c3000013.jpg    ASZ000090v  32.3099  31200.0
# 4    5  530be1183ae74079c3000015.jpg    ASZ000090x  49.9221  88400.0
#
#    areafrac  areathesh  bipolesep  c1flr24hr  id_filename  ...    hcpos_x  \
# 0      0.12     2890.0       3.72          0            1  ...  452.26991
# 1     -0.00     6170.0       7.28          0            2  ...  149.64301
# 2      0.08      937.0       3.88          0            3  ...  704.04967
# 3      0.12     1720.0       4.90          0            4  ... -449.47446
# 4      0.05     6480.0      12.48          0            5  ... -735.40990
#
#      hcpos_y m1flr12hr  m5flr12hr  n_nar  noaa    pxpos_x    pxpos_y  sszn  \
# ...

# %%
client = hek.HEKClient()

# %%
tstart = '2011/08/09 07:23:56'
tend = '2011/08/09 12:40:29'
event_type = 'FL'

# %%
t = hek.attrs.Time(tstart,tend)

# %%
e = hek.attrs.EventType(event_type)

# %%
hek.attrs.FL

# %%
result = client.search(t, e)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-36-3c6f615fcd84> in <module>
# ----> 1 result = client.search(t, e)
#
# /usr/local/lib/python3.6/dist-packages/sunpy/net/hek/hek.py in search(self, *query)
#      96
#      97         if len(ndata) == 1:
# ---> 98             return self._download(ndata[0])
#      99         else:
#     100             return self._merge(self._download(data) for data in ndata)
#
# /usr/local/lib/python3.6/dist-packages/sunpy/net/hek/hek.py in _download(self, data)
#      66             data['page'] = page
#      67             fd = urllib.request.urlopen(
# ---> 68                 self.url, urllib.parse.urlencode(data).encode('utf-8'))
#      69             try:
#      70                 result = json.load(reader(fd))
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...
